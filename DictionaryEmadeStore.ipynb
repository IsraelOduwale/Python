# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#display setting
pd.set_option('display.max_columns', None)
sns.set(style="whitegrid")

# %%
df = pd.read_csv('EmadeStore.csv', encoding='latin1')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#show values in column
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
#Dictionary
df1 = {
    'Customer Name' : ['Claire Gute', 'Darrin Van Huff',
                       "Sean O'Donnell", 'Dave Brooks', 'Chris Cortes'],
    'City' : ['Las Vegas', 'Pasadena', 'Philadelphia', 'Colorado Springs', 'Tampa']
}

#Create a dataframe
df1 = pd.DataFrame(df1,
                   columns = ['Customer Name', 'City']
                  )

# %%
df1
# Out:
#      Customer Name              City
# 0      Claire Gute         Las Vegas
# 1  Darrin Van Huff          Pasadena
# 2   Sean O'Donnell      Philadelphia
# 3      Dave Brooks  Colorado Springs
# 4     Chris Cortes             Tampa

# %%
#Dictionary
df2 = {
    'Segment' : ['Consumer', 'Corporate', 'Consumer', 'Home Office', 'Consumer'],
    'Customer Name' : ['Claire Gute', 'Darrin Van Huff',
                       "Sean O'Donnell", 'Dave Brooks', 'Chris Cortes'],
    'City' : ['Las Vegas', 'Pasadena', 'Philadelphia', 'Colorado Springs', 'Tampa'],
    'State' : ['Nevada', 'California', 'Pennsylvania', 'Colorado', 'Florida'],
    'Country' : ['United States', 'United States', 'United States','United States', 'United States']
}

#Create a dataframe
df2 = pd.DataFrame(df2,
                   columns = ['Segment','Customer Name', 'City', 'State', 'Country']
                  )
print('DataFrame Created')
# Out:
# DataFrame Created

# %%
df2
# Out:
#        Segment    Customer Name              City         State        Country
# 0     Consumer      Claire Gute         Las Vegas        Nevada  United States
# 1    Corporate  Darrin Van Huff          Pasadena    California  United States
# 2     Consumer   Sean O'Donnell      Philadelphia  Pennsylvania  United States
# 3  Home Office      Dave Brooks  Colorado Springs      Colorado  United States
# 4     Consumer     Chris Cortes             Tampa       Florida  United States

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#Checking for distinct values
df['Product Name'].unique()
# Out:
# array(['Bush Somerset Collection Bookcase',
#        'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#        'Self-Adhesive Address Labels for Typewriters by Universal', ...,
#        'Eureka Hand Vacuum, Bagless', 'LG G2',
#        'Eldon Jumbo ProFile Portable File Boxes Graphite/Black'],
#       dtype=object)

# %%
#returning particular row of a column with the row number (direct indexing)
df.at[9992, "Product Name"]     # Row 9992, column "Age"
# Out:
# 'It\'s Hot Message Books with Stickers, 2 3/4" x 5"'

# %%
#Dictionary
df3 = {
    'Category' : ['Furniture', 'Furniture', 'Office Supplies', 'Technology', 'Office Supplies'],
    'Sub-Category' : ['Bookcases', 'Chairs', 'Labels', 'Phones', 'Appliances'],
    'Product Name' : ['Bush Somerset Collection Bookcase', 'Hon Deluxe Fabric Upholstered Stacking Chairs', 
                      'Self-Adhesive Address Labels for Typewriters by Universal', 'Aastra 57i VoIP phone',
                      "It's Hot Message Books with Stickers, 2 3/4 x 5"],
    'Sales': ['261.9600', '731.9400', '14.6200', '258.5760', '29.6000'],
    'Quantity' : ['2','3','2','2','4']
}

#Create DataFrame
df3 = pd.DataFrame(df3,
                   columns = ['Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity']
                  )

#Calculating price and converting sales and quantity columns to numeric
df3['Price'] = (pd.to_numeric(df3['Sales']) * pd.to_numeric(df3['Quantity']))

#ANOTHER WAY. converting seperately before calculating
# Convert Sales and Quantity columns to numeric values
#df3['Sales'] = pd.to_numeric(df3['Sales'])
#df3['Quantity'] = pd.to_numeric(df3['Quantity'])

# Calculate price by multiplying Sales and Quantity 
#df3['Price'] = df3['Sales'] * df3['Quantity']

# %%
df3
# Out:
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3       Technology       Phones
# 4  Office Supplies   Appliances
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1      Hon Deluxe Fabric Upholstered Stacking Chairs  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3                              Aastra 57i VoIP phone  258.5760        2
# 4    It's Hot Message Books with Stickers, 2 3/4 x 5   29.6000        4
#
#       Price
# 0   523.920
# 1  2195.820
# 2    29.240
# 3   517.152
# 4   118.400
